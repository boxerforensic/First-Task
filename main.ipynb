# %%
import openai, json, requests
client = openai.OpenAI()
from openai.types.chat import ChatCompletionMessage
messages = []

url = "https://nomad-movies.nomadcoders.workers.dev/movies"

def get_popular_movie(**arguments):
    response = requests.get(url)
    movies = response.json()
    #10개만 출력하도록 수정
    return [{"id":m.get("id"),"title":m.get("title")} for m in movies[:10]]

def get_movie_details(id):
    response = requests.get(url + "/" + id)
    movies_details = response.json()
    return movies_details

def get_similar_movies(movie_name):
    response = get_popular_movie()
    id = next((movie['id'] for movie in response if movie['title'] == movie_name), None)
    response = requests.get(url + "/"+ str(id) + "/similar")
    movies = response.json()
    return [ {"id": m.get("id"), "title":m.get("title")}for m in movies ]

FUNCTION_MAP = {"get_popular_movie":get_popular_movie, "get_movie_details": get_movie_details, "get_similar_movies": get_similar_movies}

TOOLS = [ #함수 타입을 만들어줌
    {
        "type":"function",
        "function": {
            "name":"get_popular_movie",
            "description":(
                "A function that retrieves the results by searching for famous movies at 'https://nomad-movies.nomadcoders.workers.dev/movies'. The result is output as follows. (Example: List of currently popular movies. 1. god father (id number), 2. brave heart (id number) 3...)"           
                           ),
        }
    },
    {
        "type":"function",
        "function": {
            "name":"get_movie_details",
            "description":"This function takes a movie ID number as input and outputs detailed information about the movie with the specific ID as 'https://nomad-movies.nomadcoders.workers.dev/movies/{id}'. (Example: get_movie_details(500)) The output results include all information such as the movie title, movie ID, original_language, etc.",
            "parameters": {
                "type":"object",
                "properties":{
                    "id":{
                        "type":"string",
                        "description":"This is the id number that will be used to view detailed information about the movie.",
                    }
                },
                "required":["id"]
            }
        }
    },
    {
        "type":"function",
        "function": {
            "name":"get_similar_movies",
            "description":"This function takes a movie ID number as input and outputs information about movies similar to the specific ID as 'https://nomad-movies.nomadcoders.workers.dev/movies/{id}/similar'. (Example: get_similar_movies_(500)) The output results are the movie ID and movie title.",
            "parameters": {
                "type":"object",
                "properties":{
                    "movie_name":{
                        "type":"string",
                        "description":"This is to find movies of a similar type to the movies of this id.",
                    }
                },
                "required":["id"]
            }
        }
    }
]



def process_ai_response(message: ChatCompletionMessage):
    if message.tool_calls:
        messages.append({ #이작업은 messages에 tool_calls를 저장하기 위한것
            "role":"assistant",
            "content": message.content or "", #message의 content가 있으면 넣고 아니면 비워두기
            "tool_calls":[{
                "id": tool_call.id,
                "type":"function",
                "function":{
                    "name": tool_call.function.name,
                    "arguments": tool_call.function.arguments,
                }
            } 
            for tool_call in message.tool_calls #당연히 message에서 가지고 왔기 때문에 살아있음.
            ],
        })
        
        for tool_call in message.tool_calls:
            function_name = tool_call.function.name
            arguments  = tool_call.function.arguments or "{}"
            
            print(f"Agent: [{function_name}]({arguments}) 호출]")
            
            try:
                args = json.loads(arguments)
                if not isinstance(args, dict):
                    args = {}
            except json.JSONDecodeError:
                args = {}
            
            function_to_run = FUNCTION_MAP.get(function_name)
            result = function_to_run(**args) #키값을 이용해서 value를 찾아서 넣음.
            tool_content=json.dumps(result, ensure_ascii=False)
            print(f"Ran {function_name} with args {args} for a result of {tool_content}")
            messages.append({
                "role": "tool",
                "tool_call_id": tool_call.id,
                "name":function_name,
                "content":tool_content
            })
        call_ai() #더이상 tool_calls가 없으면 지금까지 messages에 데이터가 더해져서 아래쪽 else로 들어가서 한 번 더 결과를 만들어 내고 이것을 그대로 AI에다가 저장하는 것.
    else:
        messages.append({"role":"assistant", "content":message.content}) #최초 입력한 것
        print(f"Agent: {message.content}")

def call_ai():
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages = messages,
        tools = TOOLS #어떤 도구를 이용해서 calling할지 확인함.
    )
    process_ai_response(response.choices[0].message) #안에 tools call이 포함되어 있음.            
while True:
    message = input("메시지를 입력해줘")
    if message == "quit" or message =="q":
        break
    else:
        messages.append({"role":"user", "content":message})
        print(f"user: {message}")
        call_ai()
# Out:
# user: 지금 인기있는 영화를 알려줘
# Agent: [get_popular_movie]({}) 호출]
# Ran get_popular_movie with args {} for a result of [{"id": 1290821, "title": "Shelter"}, {"id": 1236153, "title": "Mercy"}, {"id": 799882, "title": "The Bluff"}, {"id": 1244975, "title": "The Orphans"}, {"id": 1088434, "title": "Hellfire"}, {"id": 1301306, "title": "A Woman Scorned"}, {"id": 1523145, "title": "Your Heart Will Be Broken"}, {"id": 680493, "title": "Return to Silent Hill"}, {"id": 1272837, "title": "28 Years Later: The Bone Temple"}, {"id": 1419406, "title": "The Shadow's Edge"}]
# Agent: 현재 인기 있는 영화 목록은 다음과 같습니다:
#
# 1. Shelter (ID: 1290821)
# 2. Mercy (ID: 1236153)
# 3. The Bluff (ID: 799882)
# 4. The Orphans (ID: 1244975)
# 5. Hellfire (ID: 1088434)
# 6. A Woman Scorned (ID: 1301306)
# 7. Your Heart Will Be Broken (ID: 1523145)
# 8. Return to Silent Hill (ID: 680493)
# 9. 28 Years Later: The Bone Temple (ID: 1272837)
# 10. The Shadow's Edge (ID: 1419406)
#
# 더 많은 정보가 필요하시면 말씀해 주세요!
# user: Mercy에 대해 더 알려줘
# Agent: [get_movie_details]({"id":"1236153"}) 호출]
# Ran get_movie_details with args {'id': '1236153'} for a result of {"adult": false, "backdrop_path": "https://image.tmdb.org/t/p/w1280/7HKpc11uQfxnw0Y8tRUYn1fsKqE.jpg", "belongs_to_collection": null, "budget": 60000000, "genres": [{"id": 878, "name": "Science Fiction"}, {"id": 28, "name": "Action"}, {"id": 53, "name": "Thriller"}], "homepage": "https://www.amazon.com/salp/mercy?hhf=", "id": 1236153, "imdb_id": "tt31050594", "origin_country": ["US"], "original_language": "en", "original_title": "Mercy", "overview": "In the near future, a detective stands on trial accused of murdering his wife. He has ninety minutes to prove his innocence to the advanced AI Judge he once championed, before it determines his fate.", "popularity": 308.7706, "poster_path": "https://image.tmdb.org/t/p/w780/pyok1kZJCfyuFapYXzHcy7BLlQa.jpg", "production_companies": [{"id": 507, "logo_path": "https://image.tmdb.org/t/p/w300/aRmHe6GWxYMRCQljF75rn2B9Gv8.png", "name": "Atlas Entertainment", "origin_country": "US"}, {"id": 210099, "logo_path": "https://image.tmdb.org/t/p/w300/g5oRCNCi8kNVb8gEoSoIcqkhjmR.png", "name": "Amazon MGM Studios", "origin_country": "US"}, {"id": 109501, "logo_path": "https://image.tmdb.org/t/p/w300/4dtmZKPLHzIALpGbdeSNX6Rw1p3.png", "name": "Bazelevs", "origin_country": "US"}], "production_countries": [{"iso_3166_1": "US", "name": "United States of America"}], "release_date": "2026-01-20", "revenue": 49463290, "runtime": 100, "spoken_languages": [{"english_name": "English", "iso_639_1": "en", "name": "English"}, {"english_name": "Hindi", "iso_639_1": "hi", "name": "हिन्दी"}], "status": "Released", "tagline": "Prove your innocence to an AI judge or face execution.", "title": "Mercy", "video": false, "vote_average": 7.131, "vote_count": 553}
# Agent: "Mercy"에 대한 자세한 정보는 다음과 같습니다:
#
# - **제목**: Mercy
# - **개봉일**: 2026년 1월 20일
# - **장르**:
#   - 과학 소설 (Science Fiction)
#   - 액션 (Action)
#   - 스릴러 (Thriller)
# - **상영 시간**: 100분
# - **예산**: 60,000,000 달러
# - **수익**: 49,463,290 달러
# - **등급**: 모든 연령 관람가 (Not Rated)
# - **상태**: 개봉됨 (Released)
# - **태그라인**: Prove your innocence to an AI judge or face execution.
# - **평점**: 7.1 (투표 수: 553)
#
# - **개요**: 가까운 미래에, 한 형사가 아내를 살해한 혐의로 재판을 받습니다. 그는 자신의 운명을 결정하는 고급 AI 판사에게 자신의 무죄를 입증할 90분의 시간을 부여받습니다.
#
# - **제작사**:
#   - Atlas Entertainment
#   - Amazon MGM Studios
#   - Bazelevs
#
# - **언어**: 영어, 힌디어
# - **홈페이지**: [Mercy](https://www.amazon.com/salp/mercy?hhf=)
#
# - **포스터**:
# ![Mercy Poster](https://image.tmdb.org/t/p/w780/pyok1kZJCfyuFapYXzHcy7BLlQa.jpg)
#
# - **배경 이미지**:
# ![Mercy Backdrop](https://image.tmdb.org/t/p/w1280/7HKpc11uQfxnw0Y8tRUYn1fsKqE.jpg)
#
# 더 궁금한 점이 있다면 말씀해 주세요!
# user: 비슷한 영화 추천해 줄래?
# Agent: [get_similar_movies]({"movie_name":"Mercy"}) 호출]
# Ran get_similar_movies with args {'movie_name': 'Mercy'} for a result of [{"id": 477234, "title": "Theru Naaigal"}, {"id": 477239, "title": "Valladesam"}, {"id": 670292, "title": "The Creator"}, {"id": 477278, "title": "The Broken Key"}, {"id": 286686, "title": "Deadly Dancer"}, {"id": 286372, "title": "Treehouse"}, {"id": 670439, "title": "Six Minutes to Midnight"}, {"id": 477489, "title": "Just a Breath Away"}, {"id": 1073486, "title": "Vaalvi"}, {"id": 481330, "title": "Coffin 2"}, {"id": 290753, "title": "Lighthouse"}, {"id": 290769, "title": "Incident at Deception Ridge"}, {"id": 674756, "title": "Jeff Drives You"}, {"id": 290859, "title": "Terminator: Dark Fate"}, {"id": 293768, "title": "Kidnap"}, {"id": 484238, "title": "The Stolen"}, {"id": 474354, "title": "22 July"}, {"id": 282854, "title": "Red Fox"}, {"id": 1070251, "title": "Murder Van"}, {"id": 666487, "title": "Tingle Monsters"}]
# Agent: "Mercy"와 비슷한 영화 목록은 다음과 같습니다:
#
# 1. **Theru Naaigal** (ID: 477234)
# 2. **Valladesam** (ID: 477239)
# 3. **The Creator** (ID: 670292)
# 4. **The Broken Key** (ID: 477278)
# 5. **Deadly Dancer** (ID: 286686)
# 6. **Treehouse** (ID: 286372)
# 7. **Six Minutes to Midnight** (ID: 670439)
# 8. **Just a Breath Away** (ID: 477489)
# 9. **Vaalvi** (ID: 1073486)
# 10. **Coffin 2** (ID: 481330)
# 11. **Lighthouse** (ID: 290753)
# 12. **Incident at Deception Ridge** (ID: 290769)
# 13. **Jeff Drives You** (ID: 674756)
# 14. **Terminator: Dark Fate** (ID: 290859)
# 15. **Kidnap** (ID: 293768)
# 16. **The Stolen** (ID: 484238)
# 17. **22 July** (ID: 474354)
# 18. **Red Fox** (ID: 282854)
# 19. **Murder Van** (ID: 1070251)
# 20. **Tingle Monsters** (ID: 666487)
#
# 이 영화들 중에서 더 궁금한 것이 있으면 말씀해 주세요!
